-- %% [markdown]
-- # [SDBSalesworks]

-- %% [markdown]
-- # [dbo].[Product]

-- %%
/****** Object:  Table [dbo].[Product]    Script Date: 2/6/2026 2:53:57 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Product](
	[ProductKey] [smallint] NOT NULL,
	[Product] [nvarchar](50) NULL,
	[Standard_Cost] [money] NULL,
	[Color] [nvarchar](50) NULL,
	[Subcategory] [nvarchar](50) NULL,
	[Category] [nvarchar](50) NULL,
	[Background_Color_Format] [nvarchar](50) NULL,
	[Font_Color_Format] [nvarchar](50) NULL,
 CONSTRAINT [PK_Product] PRIMARY KEY CLUSTERED 
(
	[ProductKey] ASC
)WITH (STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Region]

-- %%
/****** Object:  Table [dbo].[Region]    Script Date: 2/6/2026 2:53:57 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Region](
	[SalesTerritoryKey] [tinyint] NOT NULL,
	[Region] [nvarchar](50) NULL,
	[Country] [nvarchar](50) NULL,
	[Group] [nvarchar](50) NULL,
 CONSTRAINT [PK_Region] PRIMARY KEY CLUSTERED 
(
	[SalesTerritoryKey] ASC
)WITH (STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Reseller]

-- %%
/****** Object:  Table [dbo].[Reseller]    Script Date: 2/6/2026 2:53:57 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Reseller](
	[ResellerKey] [smallint] NOT NULL,
	[Business_Type] [nvarchar](50) NULL,
	[Reseller] [nvarchar](50) NULL,
	[City] [nvarchar](50) NULL,
	[State_Province] [nvarchar](50) NULL,
	[Country_Region] [nvarchar](50) NULL,
 CONSTRAINT [PK_Reseller] PRIMARY KEY CLUSTERED 
(
	[ResellerKey] ASC
)WITH (STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Sales]

-- %%
/****** Object:  Table [dbo].[Sales]    Script Date: 2/6/2026 2:53:57 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Sales](
	[SalesOrderNumber] [nvarchar](50) NULL,
	[OrderDate] [date] NULL,
	[ProductKey] [smallint] NULL,
	[ResellerKey] [smallint] NULL,
	[EmployeeKey] [smallint] NULL,
	[SalesTerritoryKey] [tinyint] NULL,
	[Quantity] [tinyint] NULL,
	[Unit_Price] [money] NULL,
	[Sales] [money] NULL,
	[Cost] [money] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Salesperson]

-- %%
/****** Object:  Table [dbo].[Salesperson]    Script Date: 2/6/2026 2:53:57 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Salesperson](
	[EmployeeKey] [smallint] NOT NULL,
	[EmployeeID] [int] NULL,
	[Salesperson] [nvarchar](50) NULL,
	[Title] [nvarchar](50) NULL,
	[UPN] [nvarchar](50) NULL,
 CONSTRAINT [PK_Salesperson] PRIMARY KEY CLUSTERED 
(
	[EmployeeKey] ASC
)WITH (STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[SalespersonRegion]

-- %%
/****** Object:  Table [dbo].[SalespersonRegion]    Script Date: 2/6/2026 2:53:57 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[SalespersonRegion](
	[EmployeeKey] [smallint] NULL,
	[SalesTerritoryKey] [tinyint] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Targets]

-- %%
/****** Object:  Table [dbo].[Targets]    Script Date: 2/6/2026 2:53:57 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Targets](
	[EmployeeID] [int] NULL,
	[Target] [money] NULL,
	[TargetMonth] [date] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [SDBSalesworks]

-- %%
ALTER DATABASE [SDBSalesworks] SET  READ_WRITE 
GO
